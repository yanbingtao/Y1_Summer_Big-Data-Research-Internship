# %%
from jieba.analyse import *
filepath=r"C:\Users\yanbi\Desktop\Sum_Research2\RawData\AllText_ForKeyWordExtract.txt"

# %%
with open(filepath,encoding ='utf8') as f:
    data = f.read()

# %%
#TF-idf method
for keyword, weight in extract_tags(data, topK=1000, withWeight=True):
    print('%s %s' % (keyword, weight))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\Public\Documents\Wondershare\CreatorTemp\jieba.cache
# Loading model cost 1.378 seconds.
# Prefix dict has been built successfully.
# 我们 0.05662284975493822
# 小区 0.04914734494058571
# 领导 0.04631290316589421
# 您好 0.037839889246348395
# 书记 0.029236716092018014
# 业主 0.02877914532938134
# 尊敬 0.028244772744964165
# 没有 0.02739084018363612
# 问题 0.026104070138567314
# 希望 0.025857424168748883
# 现在 0.02301395762145924
# 解决 0.022026995906156508
# 谢谢 0.019409009406527546
# 政府 0.01730071086060932
# 村民 0.016806082994916767
# 居民 0.016519832323439603
# 你好 0.016359399365484324
# 开发商 0.016069398748484245
# 拆迁 0.01580781421123172
# 10 0.015441570809365781
# 物业 0.015406530334764936
# 房子 0.01496823177468119
# 部门 0.01463628361088296
# 一下 0.014601941978660717
# 严重 0.014547561619341454
# 请问 0.014145780914419414
# 办理 0.013924761863316272
# 交房 0.013396985304551542
# 一直 0.012323978435147417
# 老百姓 0.012117510660449481
# ...
